# %%
import astropy
from astropy.io import fits
from astropy.wcs import WCS
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Se abren ambos archivos de output
#
# Tenemos un cubo con las imágenes procesadas, y otros con los productos de datos

# %%
cubo= fits.open('manga-8083-12705-LOGCUBE-aplan.fits.gz')
mapas= fits.open('manga-8083-12705-MAPS-aplan.fits.gz')

# %%
mapas.info()
# Out:
# Filename: manga-8083-12705-MAPS-aplan.fits.gz
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU    1397   ()
#   1  SPX_SKYCOO    1 ImageHDU        35   (72, 72, 2)   float32
#   2  SPX_ELLCOO    1 ImageHDU        40   (72, 72, 4)   float32
#   3  SPX_MFLUX     1 ImageHDU        29   (72, 72)   float32
#   4  SPX_MFLUX_IVAR    1 ImageHDU        30   (72, 72)   float32
#   5  SPX_SNR       1 ImageHDU        27   (72, 72)   float32
#   6  BINID         1 ImageHDU        37   (72, 72, 5)   int32
#   7  BIN_LWSKYCOO    1 ImageHDU        35   (72, 72, 2)   float32
#   8  BIN_LWELLCOO    1 ImageHDU        40   (72, 72, 4)   float32
#   9  BIN_AREA      1 ImageHDU        28   (72, 72)   float32
#  10  BIN_FAREA     1 ImageHDU        27   (72, 72)   float32
#  11  BIN_MFLUX     1 ImageHDU        30   (72, 72)   float32
#  12  BIN_MFLUX_IVAR    1 ImageHDU        31   (72, 72)   float32
# ...

# %%
cubo.info()
# Out:
# Filename: manga-8083-12705-LOGCUBE-aplan.fits.gz
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU    1382   ()
#   1  FLUX          1 ImageHDU        36   (72, 72, 2942)   float32
#   2  IVAR          1 ImageHDU        37   (72, 72, 2942)   float32
#   3  MASK          1 ImageHDU        36   (72, 72, 2942)   int16
#   4  LSF           1 ImageHDU        35   (72, 72, 2942)   float32
#   5  WAVE          1 ImageHDU         9   (2942,)   float32
#   6  REDCORR       1 ImageHDU         9   (2942,)   float32
#   7  MODEL         1 ImageHDU        35   (72, 72, 2942)   float32
#   8  MODEL_MASK    1 ImageHDU        35   (72, 72, 2942)   int16
#   9  EMLINE        1 ImageHDU        34   (72, 72, 2942)   float32
#  10  STELLAR       1 ImageHDU        35   (72, 72, 2942)   float32
#  11  STELLAR_MASK    1 ImageHDU        35   (72, 72, 2942)   int16
#  12  BINID         1 ImageHDU        37   (72, 72, 5)   int32

# %%
plt.imshow(mapas[23].data[24],cmap='magma')
plt.title('Mapa de emisión de Hα de MUSE')
plt.savefig('halfamuse.png')
plt.show()

# %%
plt.imshow(cubo[1].data[2000],cmap='gray')
plt.title('Imagen procesada por MaNGA')
plt.show()
